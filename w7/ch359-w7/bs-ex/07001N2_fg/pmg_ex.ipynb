# %%
from pymatgen.core import Structure
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pymatgen/core/__init__.py:49: UserWarning: Error loading .pmgrc.yaml: [Errno 2] No such file or directory: '/Users/beatrizmourino/.pmgrc.yaml'. You may need to reconfigure your yaml file.
#   warnings.warn(f"Error loading .pmgrc.yaml: {ex}. You may need to reconfigure your yaml file.")

# %%
s = Structure.from_file('UTSA80_CO.cif')

# %%
s
# Out:
# Structure Summary
# Lattice
#     abc : 15.223019999999998 18.98425 10.26784
#  angles : 79.10501 69.10527 84.93585
#  volume : 2721.565459010707
#       A : 14.221912839603474 0.0 5.429321606160553
#       B : 0.42389554089700365 18.63724348762091 3.588205096707763
#       C : 0.0 0.0 10.26784
# PeriodicSite: Zn (4.2954, 9.0502, 6.8478) [0.2875, 0.4856, 0.3452]
# PeriodicSite: Zn (10.7862, 1.1216, 12.9393) [0.7566, 0.0602, 0.8391]
# PeriodicSite: Zn (11.3842, 9.0529, 9.5574) [0.7860, 0.4857, 0.3455]
# PeriodicSite: Zn (3.6776, 1.1244, 10.2210) [0.2568, 0.0603, 0.8386]
# PeriodicSite: Zn (4.5081, 18.4052, 8.6488) [0.2875, 0.9876, 0.3452]
# PeriodicSite: Zn (10.9990, 10.4767, 14.7404) [0.7566, 0.5621, 0.8391]
# PeriodicSite: Zn (11.5968, 18.4080, 11.3584) [0.7860, 0.9877, 0.3455]
# PeriodicSite: Zn (3.8904, 10.4793, 12.0222) [0.2568, 0.5623, 0.8386]
# PeriodicSite: H (12.1853, 11.3154, 7.7020) [0.8387, 0.6071, 0.0945]
# ...

# %%
s.get_primitive_structure()
# Out:
# Structure Summary
# Lattice
#     abc : 7.611509999999999 9.492125 10.26784
#  angles : 79.10501 69.10527 84.93585
#  volume : 680.3913647526767
#       A : 7.110956419801737 0.0 2.7146608030802764
#       B : 0.21194777044850183 9.318621743810455 1.7941025483538815
#       C : 0.0 0.0 10.26784
# PeriodicSite: C (5.6803, 7.0807, 5.9809) [0.7762, 0.7598, 0.2445]
# PeriodicSite: C (6.5603, 6.1319, 5.2659) [0.9030, 0.6580, 0.1592]
# PeriodicSite: C (0.2882, 6.5364, 1.4989) [0.0196, 0.7014, 0.0182]
# PeriodicSite: C (6.5346, 4.7746, 5.6167) [0.9037, 0.5124, 0.2186]
# PeriodicSite: C (1.0690, 5.6183, 11.0779) [0.1324, 0.6029, 0.9386]
# PeriodicSite: C (0.1952, 3.8407, 2.2208) [0.0152, 0.4121, 0.1403]
# PeriodicSite: C (1.0219, 4.2498, 11.4287) [0.1301, 0.4561, 0.9990]
# PeriodicSite: C (5.0693, 3.4306, 9.6373) [0.7019, 0.3681, 0.6887]
# PeriodicSite: C (6.2229, 4.3530, 9.5579) [0.8612, 0.4671, 0.6216]
# PeriodicSite: C (6.1584, 5.4686, 8.7105) [0.8486, 0.5869, 0.5214]
# ...
